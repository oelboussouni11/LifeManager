# %% [markdown]
# <a href="https://colab.research.google.com/github/oelboussouni11/LifeManager/blob/main/tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random

# Load the Excel file
file_path = "data.xlsx"  # Update this with your actual file path
df = pd.read_excel(file_path, engine="openpyxl")  # Ensure openpyxl is used for .xlsx files

# Extract header and data
header = df.columns.tolist()  # Column names
data_list = df.values.tolist()  # Convert DataFrame to a list of lists (each row as a separate sub-array)

# Function to split the data into training (70%) and testing (30%)
def split_data(data, train_ratio=0.7):
    random.shuffle(data)  # Shuffle data for randomness
    split_index = int(len(data) * train_ratio)  # Compute split index
    training_data = data[:split_index]  # First 70% for training
    testing_data = data[split_index:]  # Remaining 30% for testing
    return training_data, testing_data

# Split the dataset
training_data, testing_data = split_data(data_list)

# training_data = training_data[:]
# testing_data = testing_data[:100]

# Counts the occurrences of each unique label return a dict
def class_counts(rows):
    counts = {}
    for row in rows:
        label = row[-1]
        counts[label] = counts.get(label, 0) + 1
    return counts

# Check if a value is numeric
def is_numeric(value):
    return isinstance(value, int) or isinstance(value, float)

# Class to represent a decision rule
class Question:
    def __init__(self, column, value):
        self.column = column
        self.value = value

    def match(self, example):
        val = example[self.column]
        return val >= self.value if is_numeric(val) else val == self.value

    def __repr__(self):
        condition = ">=" if is_numeric(self.value) else "=="
        return f"Is {header[self.column]} {condition} {self.value}?"

# Partition dataset based on a question
def partition(rows, question):
    true_rows, false_rows = [], []
    for row in rows:
        (true_rows if question.match(row) else false_rows).append(row)
    return true_rows, false_rows

# Calculate Gini impurity
def gini(rows):
    counts = class_counts(rows)
    impurity = 1 - sum((count / len(rows)) ** 2 for count in counts.values())
    return impurity

# Calculate information gain
def info_gain(left, right, current_impurity):
    p = len(left) / (len(left) + len(right))
    return current_impurity - p * gini(left) - (1 - p) * gini(right)

# Find the best question to split data
def find_best_split(rows):
    best_gain, best_question = 0, None
    current_uncertainty = gini(rows)
    n_features = len(rows[0]) - 1

    for col in range(n_features):
        values = set(row[col] for row in rows)
        for val in values:
            question = Question(col, val)
            true_rows, false_rows = partition(rows, question)
            if not true_rows or not false_rows:
                continue
            gain = info_gain(true_rows, false_rows, current_uncertainty)
            if gain >= best_gain:
                best_gain, best_question = gain, question
    return best_gain, best_question

# Leaf node (end of decision tree)
class Leaf:
    def __init__(self, rows):
        self.predictions = class_counts(rows)

# Decision node (splitting point)
class Decision_Node:
    def __init__(self, question, true_branch, false_branch):
        self.question = question
        self.true_branch = true_branch
        self.false_branch = false_branch

# Build decision tree recursively
def build_tree(rows):
    gain, question = find_best_split(rows)
    if gain == 0:
        return Leaf(rows)
    true_rows, false_rows = partition(rows, question)
    true_branch = build_tree(true_rows)
    false_branch = build_tree(false_rows)
    return Decision_Node(question, true_branch, false_branch)

# Print decision tree structure
def print_tree(node, spacing=""):
    if isinstance(node, Leaf):
        print(f"{spacing}📌 Predict: {node.predictions}")
        return
    print(f"{spacing}🔍 {node.question}")
    print(f"{spacing}├── True:")
    print_tree(node.true_branch, spacing + "│   ")
    print(f"{spacing}└── False:")
    print_tree(node.false_branch, spacing + "    ")

# Classify a new example
def classify(row, node):
    if isinstance(node, Leaf):
        return node.predictions
    return classify(row, node.true_branch if node.question.match(row) else node.false_branch)

# Get the predicted label from classification result
def get_prediction(class_counts_dict):
    return max(class_counts_dict, key=class_counts_dict.get)

if __name__ == '__main__':
    my_tree = build_tree(training_data)
    print_tree(my_tree)

    # Print actual vs predicted values
    for row in testing_data:
        prediction = get_prediction(classify(row, my_tree))
        print(f"Actual: {row[-1]}, Predicted: {prediction}")

    # Compute accuracy
    correct_predictions = sum(1 for row in testing_data if get_prediction(classify(row, my_tree)) == row[-1])
    accuracy = correct_predictions / len(testing_data) * 100
    print(f"\nModel Accuracy: {accuracy:.2f}%")
# Out:
# 🔍 Is MajorAxisLength >= 277.57139915259285?
# ├── True:
# │   🔍 Is MinorAxisLength >= 210.59271513371448?
# │   ├── True:
# │   │   🔍 Is EquivDiameter >= 386.0211352743979?
# │   │   ├── True:
# │   │   │   📌 Predict: {'BOMBAY': 364}
# │   │   └── False:
# │   │       🔍 Is ShapeFactor3 >= 0.6101963145737259?
# │   │       ├── True:
# │   │       │   🔍 Is roundness >= 0.8746267109580121?
# │   │       │   ├── True:
# │   │       │   │   🔍 Is Perimeter >= 907.665?
# │   │       │   │   ├── True:
# │   │       │   │   │   🔍 Is ShapeFactor3 >= 0.6655293476884537?
# │   │       │   │   │   ├── True:
# │   │       │   │   │   │   🔍 Is ShapeFactor4 >= 0.9942415041797283?
# │   │       │   │   │   │   ├── True:
# │   │       │   │   │   │   │   📌 Predict: {'BARBUNYA': 7}
# │   │       │   │   │   │   └── False:
# │   │       │   │   │   │       📌 Predict: {'CALI': 1}
# │   │       │   │   │   └── False:
# │   │       │   │   │       🔍 Is ShapeFactor4 >= 0.9964398974784006?
# │   │       │   │   │       ├── True:
# │   │       │   │   │       │   🔍 Is Solidity >= 0.9909265103697025?
# │   │       │   │   │       │   ├── True:
# │   │       │   │   │       │   │   🔍 Is ShapeFactor4 >= 0.9972372480156596?
# │   │       │   │   │       │   │   ├── True:
# │   │       │   │   │       │   │   │   📌 Predict: {'CALI': 6}
# │   │       │   │   │       │   │   └── False:
# │   │       │   │   │       │   │       🔍 Is ShapeFactor4 >= 0.997142836513258?
# │   │       │   │   │       │   │       ├── True:
# │   │       │   │   │       │   │       │   📌 Predict: {'BARBUNYA': 1}
# │   │       │   │   │       │   │       └── False:
# │   │       │   │   │       │   │           📌 Predict: {'CALI': 3}
# │   │       │   │   │       │   └── False:
# │   │       │   │   │       │       🔍 Is ShapeFactor3 >= 0.662192725197422?
# │   │       │   │   │       │       ├── True:
# │   │       │   │   │       │       │   📌 Predict: {'CALI': 1}
# │   │       │   │   │       │       └── False:
# │   │       │   │   │       │           📌 Predict: {'BARBUNYA': 6}
# │   │       │   │   │       └── False:
# │   │       │   │   │           🔍 Is Extent >= 0.7137639808262953?
# │   │       │   │   │           ├── True:
# │   │       │   │   │           │   🔍 Is Extent >= 0.73581732477438?
# │   │       │   │   │           │   ├── True:
# │   │       │   │   │           │   │   📌 Predict: {'CALI': 42}
# │   │       │   │   │           │   └── False:
# │   │       │   │   │           │       🔍 Is ShapeFactor3 >= 0.6344627558079181?
# │   │       │   │   │           │       ├── True:
# │   │       │   │   │           │       │   📌 Predict: {'BARBUNYA': 1}
# │   │       │   │   │           │       └── False:
# │   │       │   │   │           │           📌 Predict: {'CALI': 5}
# │   │       │   │   │           └── False:
# │   │       │   │   │               📌 Predict: {'BARBUNYA': 1}
# │   │       │   │   └── False:
# │   │       │   │       🔍 Is ShapeFactor4 >= 0.9975647093234288?
# │   │       │   │       ├── True:
# │   │       │   │       │   🔍 Is ShapeFactor1 >= 0.006054551067666146?
# │   │       │   │       │   ├── True:
# │   │       │   │       │   │   📌 Predict: {'BARBUNYA': 1}
# │   │       │   │       │   └── False:
# │   │       │   │       │       🔍 Is ShapeFactor1 >= 0.006048171828789603?
# │   │       │   │       │       ├── True:
# │   │       │   │       │       │   🔍 Is ShapeFactor4 >= 0.9981917530152938?
# │   │       │   │       │       │   ├── True:
# │   │       │   │       │       │   │   📌 Predict: {'SEKER': 1}
# │   │       │   │       │       │   └── False:
# │   │       │   │       │       │       📌 Predict: {'SIRA': 1}
# │   │       │   │       │       └── False:
# │   │       │   │       │           🔍 Is roundness >= 0.9075985264509536?
# │   │       │   │       │           ├── True:
# │   │       │   │       │           │   📌 Predict: {'SEKER': 57}
# │   │       │   │       │           └── False:
# │   │       │   │       │               🔍 Is ShapeFactor1 >= 0.005703188383170978?
# │   │       │   │       │               ├── True:
# │   │       │   │       │               │   📌 Predict: {'SEKER': 5}
# │   │       │   │       │               └── False:
# │   │       │   │       │                   📌 Predict: {'CALI': 1}
# │   │       │   │       └── False:
# │   │       │   │           🔍 Is roundness >= 0.9229896261521567?
# │   │       │   │           ├── True:
# │   │       │   │           │   🔍 Is ShapeFactor4 >= 0.997509041595235?
# │   │       │   │           │   ├── True:
# │   │       │   │           │   │   📌 Predict: {'BARBUNYA': 1}
# │   │       │   │           │   └── False:
# │   │       │   │           │       📌 Predict: {'SEKER': 6}
# │   │       │   │           └── False:
# │   │       │   │               🔍 Is roundness >= 0.8956778697211153?
# │   │       │   │               ├── True:
# │   │       │   │               │   🔍 Is ShapeFactor1 >= 0.005686257041308857?
# │   │       │   │               │   ├── True:
# │   │       │   │               │   │   🔍 Is ShapeFactor3 >= 0.629527821232539?
# │   │       │   │               │   │   ├── True:
# │   │       │   │               │   │   │   📌 Predict: {'SIRA': 13}
# │   │       │   │               │   │   └── False:
# │   │       │   │               │   │       📌 Predict: {'SEKER': 1}
# │   │       │   │               │   └── False:
# │   │       │   │               │       📌 Predict: {'SEKER': 2}
# │   │       │   │               └── False:
# │   │       │   │                   🔍 Is Solidity >= 0.9844529587058323?
# │   │       │   │                   ├── True:
# │   │       │   │                   │   🔍 Is Solidity >= 0.9903484377556028?
# │   │       │   │                   │   ├── True:
# │   │       │   │                   │   │   📌 Predict: {'SIRA': 1}
# │   │       │   │                   │   └── False:
# │   │       │   │                   │       📌 Predict: {'BARBUNYA': 7}
# │   │       │   │                   └── False:
# │   │       │   │                       🔍 Is ShapeFactor4 >= 0.9969670291906991?
# │   │       │   │                       ├── True:
# │   │       │   │                       │   📌 Predict: {'SEKER': 2}
# │   │       │   │                       └── False:
# │   │       │   │                           📌 Predict: {'SIRA': 3}
# │   │       │   └── False:
# │   │       │       🔍 Is roundness >= 0.8507927054103507?
# │   │       │       ├── True:
# │   │       │       │   🔍 Is ShapeFactor4 >= 0.9935206822464713?
# │   │       │       │   ├── True:
# │   │       │       │   │   🔍 Is ShapeFactor2 >= 0.0013271237338778267?
# │   │       │       │   │   ├── True:
# │   │       │       │   │   │   🔍 Is MajorAxisLength >= 303.9114566736381?
# │   │       │       │   │   │   ├── True:
# │   │       │       │   │   │   │   🔍 Is MinorAxisLength >= 226.0346212698494?
# │   │       │       │   │   │   │   ├── True:
# │   │       │       │   │   │   │   │   📌 Predict: {'BARBUNYA': 62}
# │   │       │       │   │   │   │   └── False:
# │   │       │       │   │   │   │       🔍 Is ShapeFactor4 >= 0.9967653728676115?
# │   │       │       │   │   │   │       ├── True:
# │   │       │       │   │   │   │       │   📌 Predict: {'BARBUNYA': 13}
# │   │       │       │   │   │   │       └── False:
# │   │       │       │   │   │   │           🔍 Is EquivDiameter >= 275.9065890851937?
# │   │       │       │   │   │   │           ├── True:
# │   │       │       │   │   │   │           │   📌 Predict: {'CALI': 3}
# │   │       │       │   │   │   │           └── False:
# │   │       │       │   │   │   │               🔍 Is ShapeFactor4 >= 0.9949610185013767?
# │   │       │       │   │   │   │               ├── True:
# │   │       │       │   │   │   │               │   📌 Predict: {'BARBUNYA': 3}
# │   │       │       │   │   │   │               └── False:
# │   │       │       │   │   │   │                   📌 Predict: {'SIRA': 1}
# │   │       │       │   │   │   └── False:
# │   │       │       │   │   │       🔍 Is ShapeFactor4 >= 0.9985443709768016?
# │   │       │       │   │   │       ├── True:
# │   │       │       │   │   │       │   📌 Predict: {'BARBUNYA': 1}
# │   │       │       │   │   │       └── False:
# │   │       │       │   │   │           📌 Predict: {'SEKER': 2}
# │   │       │       │   │   └── False:
# │   │       │       │   │       🔍 Is ShapeFactor2 >= 0.0013073944404629885?
# │   │       │       │   │       ├── True:
# │   │       │       │   │       │   📌 Predict: {'CALI': 3}
# │   │       │       │   │       └── False:
# │   │       │       │   │           🔍 Is roundness >= 0.8691564018059084?
# │   │       │       │   │           ├── True:
# │   │       │       │   │           │   📌 Predict: {'CALI': 2}
# │   │       │       │   │           └── False:
# │   │       │       │   │               🔍 Is Solidity >= 0.986807348926437?
# │   │       │       │   │               ├── True:
# │   │       │       │   │               │   📌 Predict: {'BARBUNYA': 8}
# │   │       │       │   │               └── False:
# │   │       │       │   │                   📌 Predict: {'CALI': 1}
# │   │       │       │   └── False:
# │   │       │       │       🔍 Is ShapeFactor2 >= 0.0014498437515340018?
# │   │       │       │       ├── True:
# │   │       │       │       │   🔍 Is Solidity >= 0.9851924347958717?
# │   │       │       │       │   ├── True:
# │   │       │       │       │   │   📌 Predict: {'BARBUNYA': 7}
# │   │       │       │       │   └── False:
# │   │       │       │       │       🔍 Is ShapeFactor3 >= 0.8176316669158149?
# │   │       │       │       │       ├── True:
# │   │       │       │       │       │   📌 Predict: {'BARBUNYA': 1}
# │   │       │       │       │       └── False:
# │   │       │       │       │           📌 Predict: {'CALI': 3}
# │   │       │       │       └── False:
# │   │       │       │           🔍 Is ShapeFactor3 >= 0.6562594532217325?
# │   │       │       │           ├── True:
# │   │       │       │           │   🔍 Is ShapeFactor4 >= 0.9929395864032246?
# │   │       │       │           │   ├── True:
# │   │       │       │           │   │   📌 Predict: {'CALI': 1}
# │   │       │       │           │   └── False:
# │   │       │       │           │       📌 Predict: {'BARBUNYA': 2}
# │   │       │       │           └── False:
# │   │       │       │               🔍 Is roundness >= 0.8533873043237034?
# │   │       │       │               ├── True:
# │   │       │       │               │   📌 Predict: {'CALI': 33}
# │   │       │       │               └── False:
# │   │       │       │                   🔍 Is roundness >= 0.8516068251658013?
# │   │       │       │                   ├── True:
# │   │       │       │                   │   📌 Predict: {'BARBUNYA': 1}
# │   │       │       │                   └── False:
# │   │       │       │                       📌 Predict: {'CALI': 4}
# │   │       │       └── False:
# │   │       │           🔍 Is Solidity >= 0.9883946188340808?
# │   │       │           ├── True:
# │   │       │           │   🔍 Is ShapeFactor3 >= 0.6409227020117173?
# │   │       │           │   ├── True:
# │   │       │           │   │   📌 Predict: {'BARBUNYA': 4}
# │   │       │           │   └── False:
# │   │       │           │       🔍 Is ShapeFactor2 >= 0.0014625691856697816?
# │   │       │           │       ├── True:
# │   │       │           │       │   📌 Predict: {'HOROZ': 1}
# │   │       │           │       └── False:
# │   │       │           │           🔍 Is roundness >= 0.8320537899005246?
# │   │       │           │           ├── True:
# │   │       │           │           │   📌 Predict: {'CALI': 4}
# │   │       │           │           └── False:
# │   │       │           │               📌 Predict: {'BARBUNYA': 1}
# │   │       │           └── False:
# │   │       │               🔍 Is MajorAxisLength >= 306.3289695366183?
# │   │       │               ├── True:
# │   │       │               │   🔍 Is ShapeFactor4 >= 0.978038504602479?
# │   │       │               │   ├── True:
# │   │       │               │   │   🔍 Is ShapeFactor4 >= 0.9892604002389268?
# │   │       │               │   │   ├── True:
# │   │       │               │   │   │   🔍 Is ShapeFactor2 >= 0.0012244937415425768?
# │   │       │               │   │   │   ├── True:
# │   │       │               │   │   │   │   📌 Predict: {'BARBUNYA': 495}
# │   │       │               │   │   │   └── False:
# │   │       │               │   │   │       🔍 Is ShapeFactor2 >= 0.0012193615207584656?
# │   │       │               │   │   │       ├── True:
# │   │       │               │   │   │       │   📌 Predict: {'CALI': 1}
# │   │       │               │   │   │       └── False:
# │   │       │               │   │   │           📌 Predict: {'BARBUNYA': 44}
# │   │       │               │   │   └── False:
# │   │       │               │   │       🔍 Is roundness >= 0.8391103770002777?
# │   │       │               │   │       ├── True:
# │   │       │               │   │       │   🔍 Is ShapeFactor3 >= 0.6952018080255401?
# │   │       │               │   │       │   ├── True:
# │   │       │               │   │       │   │   📌 Predict: {'BARBUNYA': 1}
# │   │       │               │   │       │   └── False:
# │   │       │               │   │       │       📌 Predict: {'CALI': 3}
# │   │       │               │   │       └── False:
# │   │       │               │   │           📌 Predict: {'BARBUNYA': 16}
# │   │       │               │   └── False:
# │   │       │               │       🔍 Is ShapeFactor4 >= 0.9696636290764395?
# │   │       │               │       ├── True:
# │   │       │               │       │   📌 Predict: {'HOROZ': 1}
# │   │       │               │       └── False:
# │   │       │               │           📌 Predict: {'CALI': 1}
# │   │       │               └── False:
# │   │       │                   🔍 Is Extent >= 0.7601078167115903?
# │   │       │                   ├── True:
# │   │       │                   │   🔍 Is ShapeFactor1 >= 0.0054563694561810035?
# │   │       │                   │   ├── True:
# │   │       │                   │   │   📌 Predict: {'BARBUNYA': 4}
# │   │       │                   │   └── False:
# │   │       │                   │       📌 Predict: {'SEKER': 1}
# │   │       │                   └── False:
# │   │       │                       📌 Predict: {'SEKER': 3}
# │   │       └── False:
# │   │           🔍 Is roundness >= 0.8006089134214006?
# │   │           ├── True:
# │   │           │   🔍 Is ShapeFactor4 >= 0.9968375519563353?
# │   │           │   ├── True:
# │   │           │   │   🔍 Is Solidity >= 0.9897961930915651?
# │   │           │   │   ├── True:
# │   │           │   │   │   🔍 Is ShapeFactor4 >= 0.9991108669955507?
# │   │           │   │   │   ├── True:
# │   │           │   │   │   │   📌 Predict: {'BARBUNYA': 1}
# │   │           │   │   │   └── False:
# │   │           │   │   │       🔍 Is roundness >= 0.8654673100101826?
# │   │           │   │   │       ├── True:
# │   │           │   │   │       │   🔍 Is roundness >= 0.8716794488375673?
# │   │           │   │   │       │   ├── True:
# │   │           │   │   │       │   │   🔍 Is Solidity >= 0.9925488749538915?
# │   │           │   │   │       │   │   ├── True:
# │   │           │   │   │       │   │   │   🔍 Is ShapeFactor4 >= 0.9973583763193337?
# │   │           │   │   │       │   │   │   ├── True:
# │   │           │   │   │       │   │   │   │   📌 Predict: {'BARBUNYA': 1}
# │   │           │   │   │       │   │   │   └── False:
# │   │           │   │   │       │   │   │       📌 Predict: {'CALI': 1}
# │   │           │   │   │       │   │   └── False:
# │   │           │   │   │       │   │       📌 Predict: {'CALI': 4}
# │   │           │   │   │       │   └── False:
# │   │           │   │   │       │       📌 Predict: {'BARBUNYA': 1}
# │   │           │   │   │       └── False:
# │   │           │   │   │           📌 Predict: {'CALI': 15}
# │   │           │   │   └── False:
# │   │           │   │       🔍 Is ShapeFactor4 >= 0.9989583842744816?
# │   │           │   │       ├── True:
# │   │           │   │       │   📌 Predict: {'CALI': 1}
# │   │           │   │       └── False:
# │   │           │   │           🔍 Is ShapeFactor2 >= 0.0010903438700433942?
# │   │           │   │           ├── True:
# │   │           │   │           │   🔍 Is ShapeFactor4 >= 0.9969382315370751?
# │   │           │   │           │   ├── True:
# │   │           │   │           │   │   📌 Predict: {'BARBUNYA': 27}
# │   │           │   │           │   └── False:
# │   │           │   │           │       🔍 Is ShapeFactor4 >= 0.9969210631662543?
# │   │           │   │           │       ├── True:
# │   │           │   │           │       │   📌 Predict: {'CALI': 1}
# │   │           │   │           │       └── False:
# │   │           │   │           │           📌 Predict: {'BARBUNYA': 2}
# │   │           │   │           └── False:
# │   │           │   │               🔍 Is ShapeFactor4 >= 0.9976053296633671?
# │   │           │   │               ├── True:
# │   │           │   │               │   📌 Predict: {'BARBUNYA': 1}
# │   │           │   │               └── False:
# │   │           │   │                   📌 Predict: {'CALI': 1}
# │   │           │   └── False:
# │   │           │       🔍 Is MajorAxisLength >= 363.98075717387303?
# │   │           │       ├── True:
# │   │           │       │   🔍 Is ShapeFactor4 >= 0.9948262359034374?
# │   │           │       │   ├── True:
# │   │           │       │   │   🔍 Is Solidity >= 0.987700776976412?
# │   │           │       │   │   ├── True:
# │   │           │       │   │   │   🔍 Is EquivDiameter >= 337.0795510448849?
# │   │           │       │   │   │   ├── True:
# │   │           │       │   │   │   │   🔍 Is ShapeFactor2 >= 0.0010292469874650407?
# │   │           │       │   │   │   │   ├── True:
# │   │           │       │   │   │   │   │   📌 Predict: {'BARBUNYA': 1}
# │   │           │       │   │   │   │   └── False:
# │   │           │       │   │   │   │       📌 Predict: {'CALI': 4}
# │   │           │       │   │   │   └── False:
# │   │           │       │   │   │       🔍 Is Solidity >= 0.9895389142415401?
# │   │           │       │   │   │       ├── True:
# │   │           │       │   │   │       │   📌 Predict: {'CALI': 68}
# │   │           │       │   │   │       └── False:
# │   │           │       │   │   │           🔍 Is Solidity >= 0.9894644183423651?
# │   │           │       │   │   │           ├── True:
# │   │           │       │   │   │           │   📌 Predict: {'BARBUNYA': 1}
# │   │           │       │   │   │           └── False:
# │   │           │       │   │   │               📌 Predict: {'CALI': 17}
# │   │           │       │   │   └── False:
# │   │           │       │   │       🔍 Is ShapeFactor3 >= 0.572098190392331?
# │   │           │       │   │       ├── True:
# │   │           │       │   │       │   📌 Predict: {'BARBUNYA': 13}
# │   │           │       │   │       └── False:
# │   │           │       │   │           🔍 Is ShapeFactor2 >= 0.0010589142551588417?
# │   │           │       │   │           ├── True:
# │   │           │       │   │           │   📌 Predict: {'CALI': 2}
# │   │           │       │   │           └── False:
# │   │           │       │   │               📌 Predict: {'BARBUNYA': 1}
# │   │           │       │   └── False:
# │   │           │       │       🔍 Is ShapeFactor1 >= 0.005945276684931743?
# │   │           │       │       ├── True:
# │   │           │       │       │   🔍 Is Extent >= 0.674604488899193?
# │   │           │       │       │   ├── True:
# │   │           │       │       │   │   🔍 Is ShapeFactor1 >= 0.005968445591376665?
# │   │           │       │       │   │   ├── True:
# │   │           │       │       │   │   │   🔍 Is Extent >= 0.8134186034684433?
# │   │           │       │       │   │   │   ├── True:
# │   │           │       │       │   │   │   │   📌 Predict: {'HOROZ': 1}
# │   │           │       │       │   │   │   └── False:
# │   │           │       │       │   │   │       🔍 Is Extent >= 0.7832806967173892?
# │   │           │       │       │   │   │       ├── True:
# │   │           │       │       │   │   │       │   🔍 Is Extent >= 0.7870979532163743?
# │   │           │       │       │   │   │       │   ├── True:
# │   │           │       │       │   │   │       │   │   📌 Predict: {'CALI': 4}
# │   │           │       │       │   │   │       │   └── False:
# │   │           │       │       │   │   │       │       📌 Predict: {'HOROZ': 1}
# │   │           │       │       │   │   │       └── False:
# │   │           │       │       │   │   │           📌 Predict: {'CALI': 19}
# │   │           │       │       │   │   └── False:
# │   │           │       │       │   │       🔍 Is ShapeFactor4 >= 0.9937792779947139?
# │   │           │       │       │   │       ├── True:
# │   │           │       │       │   │       │   📌 Predict: {'BARBUNYA': 1}
# │   │           │       │       │   │       └── False:
# │   │           │       │       │   │           📌 Predict: {'HOROZ': 2}
# │   │           │       │       │   └── False:
# │   │           │       │       │       📌 Predict: {'HOROZ': 3}
# │   │           │       │       └── False:
# │   │           │       │           🔍 Is ShapeFactor2 >= 0.0012001162778164142?
# │   │           │       │           ├── True:
# │   │           │       │           │   🔍 Is roundness >= 0.8278310251475096?
# │   │           │       │           │   ├── True:
# │   │           │       │           │   │   🔍 Is Extent >= 0.7283027965284474?
# │   │           │       │           │   │   ├── True:
# │   │           │       │           │   │   │   📌 Predict: {'CALI': 48}
# │   │           │       │           │   │   └── False:
# │   │           │       │           │   │       🔍 Is Extent >= 0.6991879946551547?
# │   │           │       │           │   │       ├── True:
# │   │           │       │           │   │       │   🔍 Is Perimeter >= 1002.0409999999999?
# │   │           │       │           │   │       │   ├── True:
# │   │           │       │           │   │       │   │   📌 Predict: {'BARBUNYA': 3}
# │   │           │       │           │   │       │   └── False:
# │   │           │       │           │   │       │       📌 Predict: {'CALI': 3}
# │   │           │       │           │   │       └── False:
# │   │           │       │           │   │           📌 Predict: {'CALI': 10}
# │   │           │       │           │   └── False:
# │   │           │       │           │       🔍 Is ShapeFactor4 >= 0.9907016104024076?
# │   │           │       │           │       ├── True:
# │   │           │       │           │       │   🔍 Is Extent >= 0.7627216522861607?
# │   │           │       │           │       │   ├── True:
# │   │           │       │           │       │   │   📌 Predict: {'BARBUNYA': 5}
# │   │           │       │           │       │   └── False:
# │   │           │       │           │       │       🔍 Is ShapeFactor4 >= 0.9931975935609962?
# │   │           │       │           │       │       ├── True:
# │   │           │       │           │       │       │   📌 Predict: {'CALI': 1}
# │   │           │       │           │       │       └── False:
# │   │           │       │           │       │           📌 Predict: {'HOROZ': 1}
# │   │           │       │           │       └── False:
# │   │           │       │           │           📌 Predict: {'CALI': 5}
# │   │           │       │           └── False:
# │   │           │       │               🔍 Is roundness >= 0.8075951221686579?
# │   │           │       │               ├── True:
# │   │           │       │               │   📌 Predict: {'CALI': 718}
# │   │           │       │               └── False:
# │   │           │       │                   🔍 Is ShapeFactor4 >= 0.994346813876827?
# │   │           │       │                   ├── True:
# │   │           │       │                   │   🔍 Is ShapeFactor4 >= 0.9945717788693881?
# │   │           │       │                   │   ├── True:
# │   │           │       │                   │   │   📌 Predict: {'HOROZ': 1}
# │   │           │       │                   │   └── False:
# │   │           │       │                   │       📌 Predict: {'BARBUNYA': 1}
# │   │           │       │                   └── False:
# │   │           │       │                       📌 Predict: {'CALI': 28}
# │   │           │       └── False:
# │   │           │           🔍 Is ConvexArea >= 60797?
# │   │           │           ├── True:
# │   │           │           │   🔍 Is Eccentricity >= 0.792207606007139?
# │   │           │           │   ├── True:
# │   │           │           │   │   🔍 Is Perimeter >= 943.911?
# │   │           │           │   │   ├── True:
# │   │           │           │   │   │   📌 Predict: {'BARBUNYA': 10}
# │   │           │           │   │   └── False:
# │   │           │           │   │       🔍 Is ShapeFactor4 >= 0.9957359643624352?
# │   │           │           │   │       ├── True:
# │   │           │           │   │       │   📌 Predict: {'SIRA': 1}
# │   │           │           │   │       └── False:
# │   │           │           │   │           📌 Predict: {'HOROZ': 1}
# │   │           │           │   └── False:
# │   │           │           │       📌 Predict: {'CALI': 2}
# │   │           │           └── False:
# │   │           │               🔍 Is EquivDiameter >= 271.9698110302769?
# │   │           │               ├── True:
# │   │           │               │   📌 Predict: {'CALI': 7}
# │   │           │               └── False:
# │   │           │                   🔍 Is ShapeFactor4 >= 0.9950682032268553?
# │   │           │                   ├── True:
# │   │           │                   │   📌 Predict: {'BARBUNYA': 1}
# │   │           │                   └── False:
# │   │           │                       📌 Predict: {'HOROZ': 1}
# │   │           └── False:
# │   │               🔍 Is ShapeFactor3 >= 0.551485527438301?
# │   │               ├── True:
# │   │               │   🔍 Is ShapeFactor4 >= 0.9908628062570098?
# │   │               │   ├── True:
# │   │               │   │   📌 Predict: {'BARBUNYA': 108}
# │   │               │   └── False:
# │   │               │       🔍 Is ShapeFactor3 >= 0.5659931731942865?
# │   │               │       ├── True:
# │   │               │       │   📌 Predict: {'BARBUNYA': 4}
# │   │               │       └── False:
# │   │               │           📌 Predict: {'CALI': 4}
# │   │               └── False:
# │   │                   🔍 Is ShapeFactor1 >= 0.0059604776295135884?
# │   │                   ├── True:
# │   │                   │   🔍 Is Perimeter >= 1030.0249999999999?
# │   │                   │   ├── True:
# │   │                   │   │   🔍 Is roundness >= 0.7993732828900599?
# │   │                   │   │   ├── True:
# │   │                   │   │   │   🔍 Is ShapeFactor4 >= 0.9962092857970993?
# │   │                   │   │   │   ├── True:
# │   │                   │   │   │   │   📌 Predict: {'HOROZ': 1}
# │   │                   │   │   │   └── False:
# │   │                   │   │   │       📌 Predict: {'CALI': 1}
# │   │                   │   │   └── False:
# │   │                   │   │       📌 Predict: {'HOROZ': 9}
# │   │                   │   └── False:
# │   │                   │       📌 Predict: {'CALI': 2}
# │   │                   └── False:
# │   │                       🔍 Is roundness >= 0.7599416058452644?
# │   │                       ├── True:
# │   │                       │   🔍 Is ShapeFactor4 >= 0.9978396596211052?
# │   │                       │   ├── True:
# │   │                       │   │   📌 Predict: {'BARBUNYA': 1}
# │   │                       │   └── False:
# │   │                       │       🔍 Is ShapeFactor2 >= 0.0010722884734235382?
# │   │                       │       ├── True:
# │   │                       │       │   📌 Predict: {'HOROZ': 1}
# │   │                       │       └── False:
# │   │                       │           🔍 Is Extent >= 0.8188571817439434?
# │   │                       │           ├── True:
# │   │                       │           │   📌 Predict: {'HOROZ': 1}
# │   │                       │           └── False:
# │   │                       │               📌 Predict: {'CALI': 19}
# │   │                       └── False:
# │   │                           🔍 Is ShapeFactor4 >= 0.994121834494904?
# │   │                           ├── True:
# │   │                           │   📌 Predict: {'BARBUNYA': 6}
# │   │                           └── False:
# │   │                               🔍 Is ShapeFactor4 >= 0.9934001696019678?
# │   │                               ├── True:
# │   │                               │   📌 Predict: {'CALI': 1}
# │   │                               └── False:
# │   │                                   📌 Predict: {'BARBUNYA': 1}
# │   └── False:
# │       🔍 Is ShapeFactor3 >= 0.549809938343349?
# │       ├── True:
# │       │   🔍 Is Perimeter >= 760.258?
# │       │   ├── True:
# │       │   │   🔍 Is roundness >= 0.8355441019670702?
# │       │   │   ├── True:
# │       │   │   │   🔍 Is roundness >= 0.923329001054187?
# │       │   │   │   ├── True:
# │       │   │   │   │   🔍 Is ShapeFactor1 >= 0.0063998313924787?
# │       │   │   │   │   ├── True:
# │       │   │   │   │   │   🔍 Is ShapeFactor1 >= 0.006483242222183134?
# │       │   │   │   │   │   ├── True:
# │       │   │   │   │   │   │   🔍 Is ShapeFactor4 >= 0.9976589441318477?
# │       │   │   │   │   │   │   ├── True:
# │       │   │   │   │   │   │   │   📌 Predict: {'SEKER': 6}
# │       │   │   │   │   │   │   └── False:
# │       │   │   │   │   │   │       📌 Predict: {'SIRA': 1}
# │       │   │   │   │   │   └── False:
# │       │   │   │   │   │       📌 Predict: {'SIRA': 5}
# │       │   │   │   │   └── False:
# │       │   │   │   │       🔍 Is Extent >= 0.8006231084208653?
# │       │   │   │   │       ├── True:
# │       │   │   │   │       │   🔍 Is ShapeFactor4 >= 0.998567945002275?
# │       │   │   │   │       │   ├── True:
# │       │   │   │   │       │   │   📌 Predict: {'SIRA': 1}
# │       │   │   │   │       │   └── False:
# │       │   │   │   │       │       📌 Predict: {'SEKER': 1}
# │       │   │   │   │       └── False:
# │       │   │   │   │           🔍 Is Solidity >= 0.990017926988266?
# │       │   │   │   │           ├── True:
# │       │   │   │   │           │   📌 Predict: {'SEKER': 19}
# │       │   │   │   │           └── False:
# │       │   │   │   │               🔍 Is ShapeFactor4 >= 0.9981319380484186?
# │       │   │   │   │               ├── True:
# │       │   │   │   │               │   📌 Predict: {'SEKER': 2}
# │       │   │   │   │               └── False:
# │       │   │   │   │                   📌 Predict: {'SIRA': 1}
# │       │   │   │   └── False:
# │       │   │   │       🔍 Is Perimeter >= 897.386?
# │       │   │   │       ├── True:
# │       │   │   │       │   🔍 Is Extent >= 0.7315599497802887?
# │       │   │   │       │   ├── True:
# │       │   │   │       │   │   🔍 Is Extent >= 0.8242589276464756?
# │       │   │   │       │   │   ├── True:
# │       │   │   │       │   │   │   📌 Predict: {'SIRA': 1}
# │       │   │   │       │   │   └── False:
# │       │   │   │       │   │       🔍 Is ShapeFactor1 >= 0.006411408656173741?
# │       │   │   │       │   │       ├── True:
# │       │   │   │       │   │       │   🔍 Is ShapeFactor4 >= 0.9942759049719948?
# │       │   │   │       │   │       │   ├── True:
# │       │   │   │       │   │       │   │   📌 Predict: {'HOROZ': 1}
# │       │   │   │       │   │       │   └── False:
# │       │   │   │       │   │       │       📌 Predict: {'CALI': 1}
# │       │   │   │       │   │       └── False:
# │       │   │   │       │   │           🔍 Is ShapeFactor3 >= 0.5958456757560511?
# │       │   │   │       │   │           ├── True:
# │       │   │   │       │   │           │   🔍 Is ShapeFactor3 >= 0.6064625344347949?
# │       │   │   │       │   │           │   ├── True:
# │       │   │   │       │   │           │   │   📌 Predict: {'CALI': 2}
# │       │   │   │       │   │           │   └── False:
# │       │   │   │       │   │           │       📌 Predict: {'SIRA': 1}
# │       │   │   │       │   │           └── False:
# │       │   │   │       │   │               📌 Predict: {'CALI': 10}
# │       │   │   │       │   └── False:
# │       │   │   │       │       🔍 Is ShapeFactor4 >= 0.998586798644832?
# │       │   │   │       │       ├── True:
# │       │   │   │       │       │   📌 Predict: {'BARBUNYA': 1}
# │       │   │   │       │       └── False:
# │       │   │   │       │           📌 Predict: {'SIRA': 6}
# │       │   │   │       └── False:
# │       │   │   │           🔍 Is EquivDiameter >= 231.38377129040154?
# │       │   │   │           ├── True:
# │       │   │   │           │   🔍 Is ShapeFactor4 >= 0.9989925047784913?
# │       │   │   │           │   ├── True:
# │       │   │   │           │   │   🔍 Is roundness >= 0.8986146489478722?
# │       │   │   │           │   │   ├── True:
# │       │   │   │           │   │   │   📌 Predict: {'SEKER': 6}
# │       │   │   │           │   │   └── False:
# │       │   │   │           │   │       📌 Predict: {'SIRA': 2}
# │       │   │   │           │   └── False:
# │       │   │   │           │       🔍 Is ShapeFactor4 >= 0.9787860281799222?
# │       │   │   │           │       ├── True:
# │       │   │   │           │       │   🔍 Is ShapeFactor1 >= 0.007251194508035834?
# │       │   │   │           │       │   ├── True:
# │       │   │   │           │       │   │   🔍 Is ShapeFactor4 >= 0.996537587146226?
# │       │   │   │           │       │   │   ├── True:
# │       │   │   │           │       │   │   │   📌 Predict: {'SIRA': 1}
# │       │   │   │           │       │   │   └── False:
# │       │   │   │           │       │   │       📌 Predict: {'HOROZ': 3}
# │       │   │   │           │       │   └── False:
# │       │   │   │           │       │       🔍 Is ShapeFactor1 >= 0.0061535558110875225?
# │       │   │   │           │       │       ├── True:
# │       │   │   │           │       │       │   🔍 Is roundness >= 0.9189194384077817?
# │       │   │   │           │       │       │   ├── True:
# │       │   │   │           │       │       │   │   🔍 Is ShapeFactor4 >= 0.9982570707275948?
# │       │   │   │           │       │       │   │   ├── True:
# │       │   │   │           │       │       │   │   │   🔍 Is EquivDiameter >= 237.9168141184879?
# │       │   │   │           │       │       │   │   │   ├── True:
# │       │   │   │           │       │       │   │   │   │   📌 Predict: {'SIRA': 1}
# │       │   │   │           │       │       │   │   │   └── False:
# │       │   │   │           │       │       │   │   │       📌 Predict: {'SEKER': 3}
# │       │   │   │           │       │       │   │   └── False:
# │       │   │   │           │       │       │   │       🔍 Is Solidity >= 0.9920021327645961?
# │       │   │   │           │       │       │   │       ├── True:
# │       │   │   │           │       │       │   │       │   📌 Predict: {'SEKER': 1}
# │       │   │   │           │       │       │   │       └── False:
# │       │   │   │           │       │       │   │           📌 Predict: {'SIRA': 12}
# │       │   │   │           │       │       │   └── False:
# │       │   │   │           │       │       │       🔍 Is Perimeter >= 876.6329999999999?
# │       │   │   │           │       │       │       ├── True:
# │       │   │   │           │       │       │       │   🔍 Is ShapeFactor4 >= 0.9886308172855555?
# │       │   │   │           │       │       │       │   ├── True:
# │       │   │   │           │       │       │       │   │   🔍 Is ShapeFactor4 >= 0.9979221625070284?
# │       │   │   │           │       │       │       │   │   ├── True:
# │       │   │   │           │       │       │       │   │   │   📌 Predict: {'BARBUNYA': 1}
# │       │   │   │           │       │       │       │   │   └── False:
# │       │   │   │           │       │       │       │   │       🔍 Is Perimeter >= 876.7049999999999?
# │       │   │   │           │       │       │       │   │       ├── True:
# │       │   │   │           │       │       │       │   │       │   🔍 Is Solidity >= 0.9908303896626828?
# │       │   │   │           │       │       │       │   │       │   ├── True:
# │       │   │   │           │       │       │       │   │       │   │   🔍 Is ShapeFactor3 >= 0.6043199546476298?
# │       │   │   │           │       │       │       │   │       │   │   ├── True:
# │       │   │   │           │       │       │       │   │       │   │   │   📌 Predict: {'SEKER': 1}
# │       │   │   │           │       │       │       │   │       │   │   └── False:
# │       │   │   │           │       │       │       │   │       │   │       📌 Predict: {'SIRA': 2}
# │       │   │   │           │       │       │       │   │       │   └── False:
# │       │   │   │           │       │       │       │   │       │       🔍 Is EquivDiameter >= 258.88126605883394?
# │       │   │   │           │       │       │       │   │       │       ├── True:
# │       │   │   │           │       │       │       │   │       │       │   📌 Predict: {'SIRA': 27}
# │       │   │   │           │       │       │       │   │       │       └── False:
# │       │   │   │           │       │       │       │   │       │           🔍 Is ShapeFactor4 >= 0.9958575335598879?
# │       │   │   │           │       │       │       │   │       │           ├── True:
# │       │   │   │           │       │       │       │   │       │           │   📌 Predict: {'CALI': 1}
# │       │   │   │           │       │       │       │   │       │           └── False:
# │       │   │   │           │       │       │       │   │       │               📌 Predict: {'SIRA': 2}
# │       │   │   │           │       │       │       │   │       └── False:
# │       │   │   │           │       │       │       │   │           📌 Predict: {'HOROZ': 1}
# │       │   │   │           │       │       │       │   └── False:
# │       │   │   │           │       │       │       │       🔍 Is ShapeFactor4 >= 0.98831624196834?
# │       │   │   │           │       │       │       │       ├── True:
# │       │   │   │           │       │       │       │       │   📌 Predict: {'CALI': 1}
# │       │   │   │           │       │       │       │       └── False:
# │       │   │   │           │       │       │       │           🔍 Is ShapeFactor3 >= 0.5704753836017475?
# │       │   │   │           │       │       │       │           ├── True:
# │       │   │   │           │       │       │       │           │   📌 Predict: {'HOROZ': 2}
# │       │   │   │           │       │       │       │           └── False:
# │       │   │   │           │       │       │       │               📌 Predict: {'SIRA': 1}
# │       │   │   │           │       │       │       └── False:
# │       │   │   │           │       │       │           🔍 Is ShapeFactor3 >= 0.5504418228368553?
# │       │   │   │           │       │       │           ├── True:
# │       │   │   │           │       │       │           │   🔍 Is ShapeFactor4 >= 0.9988495891919492?
# │       │   │   │           │       │       │           │   ├── True:
# │       │   │   │           │       │       │           │   │   🔍 Is ShapeFactor4 >= 0.9989017618453653?
# │       │   │   │           │       │       │           │   │   ├── True:
# │       │   │   │           │       │       │           │   │   │   📌 Predict: {'SIRA': 5}
# │       │   │   │           │       │       │           │   │   └── False:
# │       │   │   │           │       │       │           │   │       🔍 Is ShapeFactor4 >= 0.9988831191690855?
# │       │   │   │           │       │       │           │   │       ├── True:
# │       │   │   │           │       │       │           │   │       │   📌 Predict: {'SEKER': 1}
# │       │   │   │           │       │       │           │   │       └── False:
# │       │   │   │           │       │       │           │   │           📌 Predict: {'CALI': 1}
# │       │   │   │           │       │       │           │   └── False:
# │       │   │   │           │       │       │           │       🔍 Is roundness >= 0.8375363806334598?
# │       │   │   │           │       │       │           │       ├── True:
# │       │   │   │           │       │       │           │       │   🔍 Is MinorAxisLength >= 182.21077917001838?
# │       │   │   │           │       │       │           │       │   ├── True:
# │       │   │   │           │       │       │           │       │   │   🔍 Is ShapeFactor4 >= 0.9977054776835995?
# │       │   │   │           │       │       │           │       │   │   ├── True:
# │       │   │   │           │       │       │           │       │   │   │   🔍 Is ShapeFactor4 >= 0.9977097883260287?
# │       │   │   │           │       │       │           │       │   │   │   ├── True:
# │       │   │   │           │       │       │           │       │   │   │   │   🔍 Is Eccentricity >= 0.7191539052348436?
# │       │   │   │           │       │       │           │       │   │   │   │   ├── True:
# │       │   │   │           │       │       │           │       │   │   │   │   │   🔍 Is Perimeter >= 773.5429999999999?
# │       │   │   │           │       │       │           │       │   │   │   │   │   ├── True:
# │       │   │   │           │       │       │           │       │   │   │   │   │   │   🔍 Is ShapeFactor4 >= 0.9977824715136341?
# │       │   │   │           │       │       │           │       │   │   │   │   │   │   ├── True:
# │       │   │   │           │       │       │           │       │   │   │   │   │   │   │   🔍 Is Solidity >= 0.9880287310454908?
# │       │   │   │           │       │       │           │       │   │   │   │   │   │   │   ├── True:
# │       │   │   │           │       │       │           │       │   │   │   │   │   │   │   │   📌 Predict: {'SIRA': 97}
# │       │   │   │           │       │       │           │       │   │   │   │   │   │   │   └── False:
# │       │   │   │           │       │       │           │       │   │   │   │   │   │   │       🔍 Is ShapeFactor1 >= 0.0065559080182289444?
# │       │   │   │           │       │       │           │       │   │   │   │   │   │   │       ├── True:
# │       │   │   │           │       │       │           │       │   │   │   │   │   │   │       │   📌 Predict: {'SIRA': 12}
# │       │   │   │           │       │       │           │       │   │   │   │   │   │   │       └── False:
# │       │   │   │           │       │       │           │       │   │   │   │   │   │   │           📌 Predict: {'BARBUNYA': 1}
# │       │   │   │           │       │       │           │       │   │   │   │   │   │   └── False:
# │       │   │   │           │       │       │           │       │   │   │   │   │   │       🔍 Is ShapeFactor4 >= 0.9977711665618465?
# │       │   │   │           │       │       │           │       │   │   │   │   │   │       ├── True:
# │       │   │   │           │       │       │           │       │   │   │   │   │   │       │   📌 Predict: {'SEKER': 1}
# │       │   │   │           │       │       │           │       │   │   │   │   │   │       └── False:
# │       │   │   │           │       │       │           │       │   │   │   │   │   │           📌 Predict: {'SIRA': 12}
# │       │   │   │           │       │       │           │       │   │   │   │   │   └── False:
# │       │   │   │           │       │       │           │       │   │   │   │   │       🔍 Is Extent >= 0.7074637249055854?
# │       │   │   │           │       │       │           │       │   │   │   │   │       ├── True:
# │       │   │   │           │       │       │           │       │   │   │   │   │       │   📌 Predict: {'SIRA': 10}
# │       │   │   │           │       │       │           │       │   │   │   │   │       └── False:
# │       │   │   │           │       │       │           │       │   │   │   │   │           📌 Predict: {'SEKER': 1}
# │       │   │   │           │       │       │           │       │   │   │   │   └── False:
# │       │   │   │           │       │       │           │       │   │   │   │       🔍 Is ShapeFactor3 >= 0.7049782252951083?
# │       │   │   │           │       │       │           │       │   │   │   │       ├── True:
# │       │   │   │           │       │       │           │       │   │   │   │       │   📌 Predict: {'SIRA': 2}
# │       │   │   │           │       │       │           │       │   │   │   │       └── False:
# │       │   │   │           │       │       │           │       │   │   │   │           📌 Predict: {'SEKER': 1}
# │       │   │   │           │       │       │           │       │   │   │   └── False:
# │       │   │   │           │       │       │           │       │   │   │       📌 Predict: {'HOROZ': 1}
# │       │   │   │           │       │       │           │       │   │   └── False:
# │       │   │   │           │       │       │           │       │   │       🔍 Is Solidity >= 0.9858427174567866?
# │       │   │   │           │       │       │           │       │   │       ├── True:
# │       │   │   │           │       │       │           │       │   │       │   🔍 Is ShapeFactor4 >= 0.9956880962222152?
# │       │   │   │           │       │       │           │       │   │       │   ├── True:
# │       │   │   │           │       │       │           │       │   │       │   │   📌 Predict: {'SIRA': 464}
# │       │   │   │           │       │       │           │       │   │       │   └── False:
# │       │   │   │           │       │       │           │       │   │       │       🔍 Is ShapeFactor4 >= 0.9956823194644034?
# │       │   │   │           │       │       │           │       │   │       │       ├── True:
# │       │   │   │           │       │       │           │       │   │       │       │   📌 Predict: {'SEKER': 1}
# │       │   │   │           │       │       │           │       │   │       │       └── False:
# │       │   │   │           │       │       │           │       │   │       │           🔍 Is MinorAxisLength >= 187.09607803975285?
# │       │   │   │           │       │       │           │       │   │       │           ├── True:
# │       │   │   │           │       │       │           │       │   │       │           │   🔍 Is ShapeFactor4 >= 0.9955953572829827?
# │       │   │   │           │       │       │           │       │   │       │           │   ├── True:
# │       │   │   │           │       │       │           │       │   │       │           │   │   🔍 Is ShapeFactor4 >= 0.9955973097937226?
# │       │   │   │           │       │       │           │       │   │       │           │   │   ├── True:
# │       │   │   │           │       │       │           │       │   │       │           │   │   │   📌 Predict: {'SIRA': 13}
# │       │   │   │           │       │       │           │       │   │       │           │   │   └── False:
# │       │   │   │           │       │       │           │       │   │       │           │   │       📌 Predict: {'HOROZ': 1}
# │       │   │   │           │       │       │           │       │   │       │           │   └── False:
# │       │   │   │           │       │       │           │       │   │       │           │       🔍 Is Eccentricity >= 0.7257652538091347?
# │       │   │   │           │       │       │           │       │   │       │           │       ├── True:
# │       │   │   │           │       │       │           │       │   │       │           │       │   🔍 Is Extent >= 0.8065392823796185?
# │       │   │   │           │       │       │           │       │   │       │           │       │   ├── True:
# │       │   │   │           │       │       │           │       │   │       │           │       │   │   🔍 Is Extent >= 0.807200351796264?
# │       │   │   │           │       │       │           │       │   │       │           │       │   │   ├── True:
# │       │   │   │           │       │       │           │       │   │       │           │       │   │   │   📌 Predict: {'SIRA': 38}
# │       │   │   │           │       │       │           │       │   │       │           │       │   │   └── False:
# │       │   │   │           │       │       │           │       │   │       │           │       │   │       📌 Predict: {'CALI': 1}
# │       │   │   │           │       │       │           │       │   │       │           │       │   └── False:
# │       │   │   │           │       │       │           │       │   │       │           │       │       📌 Predict: {'SIRA': 271}
# │       │   │   │           │       │       │           │       │   │       │           │       └── False:
# │       │   │   │           │       │       │           │       │   │       │           │           🔍 Is ShapeFactor3 >= 0.6849342574733587?
# │       │   │   │           │       │       │           │       │   │       │           │           ├── True:
# │       │   │   │           │       │       │           │       │   │       │           │           │   📌 Predict: {'SIRA': 19}
# │       │   │   │           │       │       │           │       │   │       │           │           └── False:
# │       │   │   │           │       │       │           │       │   │       │           │               📌 Predict: {'SEKER': 1}
# │       │   │   │           │       │       │           │       │   │       │           └── False:
# ...
# Actual: HOROZ, Predicted: HOROZ
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: HOROZ, Predicted: HOROZ
# Actual: SEKER, Predicted: SEKER
# Actual: HOROZ, Predicted: HOROZ
# Actual: SIRA, Predicted: SIRA
# Actual: HOROZ, Predicted: HOROZ
# Actual: DERMASON, Predicted: DERMASON
# Actual: DERMASON, Predicted: DERMASON
# Actual: DERMASON, Predicted: DERMASON
# Actual: BARBUNYA, Predicted: HOROZ
# Actual: SIRA, Predicted: SIRA
# Actual: BOMBAY, Predicted: BOMBAY
# Actual: HOROZ, Predicted: HOROZ
# Actual: SEKER, Predicted: SEKER
# Actual: HOROZ, Predicted: HOROZ
# Actual: HOROZ, Predicted: HOROZ
# Actual: DERMASON, Predicted: DERMASON
# Actual: SEKER, Predicted: SEKER
# Actual: HOROZ, Predicted: HOROZ
# Actual: BARBUNYA, Predicted: CALI
# Actual: DERMASON, Predicted: SIRA
# Actual: HOROZ, Predicted: HOROZ
# Actual: SIRA, Predicted: SIRA
# Actual: SEKER, Predicted: SEKER
# Actual: HOROZ, Predicted: HOROZ
# Actual: DERMASON, Predicted: SIRA
# Actual: DERMASON, Predicted: DERMASON
# Actual: HOROZ, Predicted: HOROZ
# Actual: CALI, Predicted: CALI
# Actual: SEKER, Predicted: SEKER
# Actual: SIRA, Predicted: SIRA
# Actual: DERMASON, Predicted: DERMASON
# Actual: CALI, Predicted: CALI
# Actual: SEKER, Predicted: SEKER
# Actual: DERMASON, Predicted: DERMASON
# Actual: SIRA, Predicted: SIRA
# Actual: DERMASON, Predicted: DERMASON
# Actual: DERMASON, Predicted: DERMASON
# Actual: DERMASON, Predicted: DERMASON
# Actual: HOROZ, Predicted: HOROZ
# Actual: SEKER, Predicted: SEKER
# Actual: DERMASON, Predicted: SEKER
# Actual: SIRA, Predicted: SIRA
# Actual: DERMASON, Predicted: DERMASON
# Actual: CALI, Predicted: CALI
# Actual: SIRA, Predicted: SIRA
# Actual: SIRA, Predicted: SIRA
# Actual: SEKER, Predicted: SEKER
# Actual: SIRA, Predicted: SIRA
# Actual: HOROZ, Predicted: HOROZ
# Actual: HOROZ, Predicted: HOROZ
# Actual: HOROZ, Predicted: HOROZ
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: SIRA, Predicted: SIRA
# Actual: DERMASON, Predicted: DERMASON
# Actual: SEKER, Predicted: SEKER
# Actual: CALI, Predicted: CALI
# Actual: HOROZ, Predicted: DERMASON
# Actual: CALI, Predicted: CALI
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: SEKER, Predicted: SEKER
# Actual: SEKER, Predicted: SEKER
# Actual: SIRA, Predicted: SIRA
# Actual: SEKER, Predicted: SEKER
# Actual: SEKER, Predicted: SEKER
# Actual: SEKER, Predicted: SEKER
# Actual: DERMASON, Predicted: DERMASON
# Actual: SEKER, Predicted: SEKER
# Actual: DERMASON, Predicted: SIRA
# Actual: DERMASON, Predicted: DERMASON
# Actual: SIRA, Predicted: SIRA
# Actual: DERMASON, Predicted: DERMASON
# Actual: DERMASON, Predicted: DERMASON
# Actual: SEKER, Predicted: SEKER
# Actual: SIRA, Predicted: SIRA
# Actual: DERMASON, Predicted: DERMASON
# Actual: SEKER, Predicted: SEKER
# Actual: SIRA, Predicted: DERMASON
# Actual: SIRA, Predicted: SIRA
# Actual: HOROZ, Predicted: HOROZ
# Actual: HOROZ, Predicted: SIRA
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: SIRA, Predicted: SIRA
# Actual: CALI, Predicted: CALI
# Actual: DERMASON, Predicted: DERMASON
# Actual: SEKER, Predicted: SEKER
# Actual: BOMBAY, Predicted: BOMBAY
# Actual: DERMASON, Predicted: DERMASON
# Actual: SIRA, Predicted: SIRA
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: DERMASON, Predicted: DERMASON
# Actual: SIRA, Predicted: DERMASON
# Actual: CALI, Predicted: CALI
# Actual: BARBUNYA, Predicted: HOROZ
# Actual: HOROZ, Predicted: CALI
# Actual: HOROZ, Predicted: HOROZ
# Actual: DERMASON, Predicted: DERMASON
# Actual: DERMASON, Predicted: DERMASON
# Actual: SEKER, Predicted: SEKER
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: DERMASON, Predicted: DERMASON
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: CALI, Predicted: CALI
# Actual: DERMASON, Predicted: DERMASON
# Actual: SIRA, Predicted: SIRA
# Actual: CALI, Predicted: CALI
# Actual: DERMASON, Predicted: DERMASON
# Actual: DERMASON, Predicted: DERMASON
# Actual: SIRA, Predicted: SIRA
# Actual: DERMASON, Predicted: DERMASON
# Actual: HOROZ, Predicted: HOROZ
# Actual: HOROZ, Predicted: HOROZ
# Actual: DERMASON, Predicted: DERMASON
# Actual: DERMASON, Predicted: DERMASON
# Actual: SEKER, Predicted: SEKER
# Actual: SIRA, Predicted: SIRA
# Actual: DERMASON, Predicted: DERMASON
# Actual: CALI, Predicted: CALI
# Actual: CALI, Predicted: CALI
# Actual: SEKER, Predicted: SEKER
# Actual: SIRA, Predicted: SIRA
# Actual: BOMBAY, Predicted: BOMBAY
# Actual: DERMASON, Predicted: DERMASON
# Actual: SIRA, Predicted: SIRA
# Actual: DERMASON, Predicted: DERMASON
# Actual: CALI, Predicted: CALI
# Actual: SIRA, Predicted: SIRA
# Actual: SEKER, Predicted: SEKER
# Actual: DERMASON, Predicted: DERMASON
# Actual: HOROZ, Predicted: HOROZ
# Actual: SIRA, Predicted: SIRA
# Actual: HOROZ, Predicted: HOROZ
# Actual: SIRA, Predicted: SIRA
# Actual: SIRA, Predicted: SIRA
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: DERMASON, Predicted: DERMASON
# Actual: HOROZ, Predicted: HOROZ
# Actual: SEKER, Predicted: SEKER
# Actual: DERMASON, Predicted: DERMASON
# Actual: HOROZ, Predicted: HOROZ
# Actual: HOROZ, Predicted: HOROZ
# Actual: SEKER, Predicted: SEKER
# Actual: HOROZ, Predicted: HOROZ
# Actual: DERMASON, Predicted: DERMASON
# Actual: DERMASON, Predicted: SIRA
# Actual: SEKER, Predicted: SEKER
# Actual: DERMASON, Predicted: DERMASON
# Actual: SEKER, Predicted: SEKER
# Actual: DERMASON, Predicted: DERMASON
# Actual: HOROZ, Predicted: HOROZ
# Actual: DERMASON, Predicted: SIRA
# Actual: BOMBAY, Predicted: BOMBAY
# Actual: DERMASON, Predicted: SEKER
# Actual: CALI, Predicted: CALI
# Actual: SIRA, Predicted: SIRA
# Actual: DERMASON, Predicted: DERMASON
# Actual: DERMASON, Predicted: DERMASON
# Actual: DERMASON, Predicted: SIRA
# Actual: DERMASON, Predicted: DERMASON
# Actual: SIRA, Predicted: HOROZ
# Actual: HOROZ, Predicted: HOROZ
# Actual: SIRA, Predicted: HOROZ
# Actual: HOROZ, Predicted: HOROZ
# Actual: SIRA, Predicted: SIRA
# Actual: HOROZ, Predicted: HOROZ
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: SIRA, Predicted: SIRA
# Actual: HOROZ, Predicted: HOROZ
# Actual: SIRA, Predicted: SIRA
# Actual: DERMASON, Predicted: DERMASON
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: DERMASON, Predicted: DERMASON
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: DERMASON, Predicted: DERMASON
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: DERMASON, Predicted: DERMASON
# Actual: SEKER, Predicted: SEKER
# Actual: DERMASON, Predicted: DERMASON
# Actual: DERMASON, Predicted: DERMASON
# Actual: BOMBAY, Predicted: BOMBAY
# Actual: SIRA, Predicted: SIRA
# Actual: SEKER, Predicted: SEKER
# Actual: CALI, Predicted: CALI
# Actual: DERMASON, Predicted: DERMASON
# Actual: SIRA, Predicted: SIRA
# Actual: CALI, Predicted: CALI
# Actual: SIRA, Predicted: SIRA
# Actual: HOROZ, Predicted: HOROZ
# Actual: DERMASON, Predicted: DERMASON
# Actual: SEKER, Predicted: SEKER
# Actual: DERMASON, Predicted: DERMASON
# Actual: SEKER, Predicted: SEKER
# Actual: HOROZ, Predicted: HOROZ
# Actual: SIRA, Predicted: SIRA
# Actual: CALI, Predicted: CALI
# Actual: DERMASON, Predicted: DERMASON
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: SIRA, Predicted: SIRA
# Actual: DERMASON, Predicted: DERMASON
# Actual: HOROZ, Predicted: CALI
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: DERMASON, Predicted: DERMASON
# Actual: DERMASON, Predicted: DERMASON
# Actual: SIRA, Predicted: DERMASON
# Actual: SEKER, Predicted: SEKER
# Actual: SIRA, Predicted: SIRA
# Actual: BOMBAY, Predicted: BOMBAY
# Actual: CALI, Predicted: CALI
# Actual: CALI, Predicted: CALI
# Actual: DERMASON, Predicted: DERMASON
# Actual: DERMASON, Predicted: DERMASON
# Actual: DERMASON, Predicted: SIRA
# Actual: CALI, Predicted: CALI
# Actual: DERMASON, Predicted: DERMASON
# Actual: SIRA, Predicted: SIRA
# Actual: DERMASON, Predicted: DERMASON
# Actual: DERMASON, Predicted: DERMASON
# Actual: SEKER, Predicted: SEKER
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: DERMASON, Predicted: DERMASON
# Actual: SIRA, Predicted: SIRA
# Actual: DERMASON, Predicted: SIRA
# Actual: DERMASON, Predicted: DERMASON
# Actual: BOMBAY, Predicted: BOMBAY
# Actual: HOROZ, Predicted: HOROZ
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: HOROZ, Predicted: HOROZ
# Actual: CALI, Predicted: CALI
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: CALI, Predicted: CALI
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: HOROZ, Predicted: DERMASON
# Actual: SIRA, Predicted: SIRA
# Actual: SIRA, Predicted: SIRA
# Actual: DERMASON, Predicted: DERMASON
# Actual: SIRA, Predicted: SIRA
# Actual: SIRA, Predicted: SIRA
# Actual: BOMBAY, Predicted: BOMBAY
# Actual: DERMASON, Predicted: DERMASON
# Actual: SEKER, Predicted: SEKER
# Actual: CALI, Predicted: CALI
# Actual: SEKER, Predicted: SEKER
# Actual: CALI, Predicted: CALI
# Actual: HOROZ, Predicted: HOROZ
# Actual: DERMASON, Predicted: DERMASON
# Actual: HOROZ, Predicted: HOROZ
# Actual: DERMASON, Predicted: DERMASON
# Actual: CALI, Predicted: CALI
# Actual: CALI, Predicted: CALI
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: CALI, Predicted: CALI
# Actual: SIRA, Predicted: SIRA
# Actual: SEKER, Predicted: SEKER
# Actual: SEKER, Predicted: SEKER
# Actual: DERMASON, Predicted: DERMASON
# Actual: SIRA, Predicted: SIRA
# Actual: BOMBAY, Predicted: BOMBAY
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: SIRA, Predicted: SIRA
# Actual: CALI, Predicted: CALI
# Actual: SEKER, Predicted: SIRA
# Actual: DERMASON, Predicted: DERMASON
# Actual: DERMASON, Predicted: DERMASON
# Actual: HOROZ, Predicted: HOROZ
# Actual: DERMASON, Predicted: DERMASON
# Actual: BOMBAY, Predicted: BOMBAY
# Actual: SIRA, Predicted: SIRA
# Actual: DERMASON, Predicted: DERMASON
# Actual: BARBUNYA, Predicted: SIRA
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: DERMASON, Predicted: DERMASON
# Actual: DERMASON, Predicted: DERMASON
# Actual: SIRA, Predicted: HOROZ
# Actual: SIRA, Predicted: SIRA
# Actual: DERMASON, Predicted: SIRA
# Actual: SEKER, Predicted: SEKER
# Actual: CALI, Predicted: BARBUNYA
# Actual: SEKER, Predicted: SEKER
# Actual: DERMASON, Predicted: DERMASON
# Actual: HOROZ, Predicted: HOROZ
# Actual: SEKER, Predicted: SEKER
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: SIRA, Predicted: SIRA
# Actual: SEKER, Predicted: SEKER
# Actual: DERMASON, Predicted: DERMASON
# Actual: CALI, Predicted: CALI
# Actual: HOROZ, Predicted: HOROZ
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: SIRA, Predicted: SIRA
# Actual: SEKER, Predicted: SEKER
# Actual: SEKER, Predicted: SEKER
# Actual: SIRA, Predicted: SIRA
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: SIRA, Predicted: SIRA
# Actual: HOROZ, Predicted: HOROZ
# Actual: SEKER, Predicted: SEKER
# Actual: CALI, Predicted: CALI
# Actual: HOROZ, Predicted: HOROZ
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: HOROZ, Predicted: HOROZ
# Actual: CALI, Predicted: CALI
# Actual: SIRA, Predicted: HOROZ
# Actual: SEKER, Predicted: SEKER
# Actual: SIRA, Predicted: SIRA
# Actual: DERMASON, Predicted: DERMASON
# Actual: DERMASON, Predicted: DERMASON
# Actual: SIRA, Predicted: SIRA
# Actual: CALI, Predicted: CALI
# Actual: HOROZ, Predicted: HOROZ
# Actual: DERMASON, Predicted: SEKER
# Actual: HOROZ, Predicted: HOROZ
# Actual: SIRA, Predicted: HOROZ
# Actual: SEKER, Predicted: SEKER
# Actual: HOROZ, Predicted: HOROZ
# Actual: DERMASON, Predicted: DERMASON
# Actual: SEKER, Predicted: SEKER
# Actual: DERMASON, Predicted: DERMASON
# Actual: SIRA, Predicted: SIRA
# Actual: SEKER, Predicted: SEKER
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: CALI, Predicted: BARBUNYA
# Actual: DERMASON, Predicted: SIRA
# Actual: CALI, Predicted: BARBUNYA
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: CALI, Predicted: CALI
# Actual: CALI, Predicted: CALI
# Actual: SIRA, Predicted: SIRA
# Actual: BOMBAY, Predicted: BOMBAY
# Actual: CALI, Predicted: SEKER
# Actual: DERMASON, Predicted: DERMASON
# Actual: CALI, Predicted: CALI
# Actual: SEKER, Predicted: SEKER
# Actual: DERMASON, Predicted: DERMASON
# Actual: HOROZ, Predicted: HOROZ
# Actual: HOROZ, Predicted: HOROZ
# Actual: DERMASON, Predicted: DERMASON
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: DERMASON, Predicted: DERMASON
# Actual: SIRA, Predicted: SIRA
# Actual: DERMASON, Predicted: DERMASON
# Actual: DERMASON, Predicted: DERMASON
# Actual: DERMASON, Predicted: DERMASON
# Actual: HOROZ, Predicted: HOROZ
# Actual: SIRA, Predicted: HOROZ
# Actual: DERMASON, Predicted: DERMASON
# Actual: CALI, Predicted: CALI
# Actual: HOROZ, Predicted: HOROZ
# Actual: CALI, Predicted: CALI
# Actual: SEKER, Predicted: SEKER
# Actual: DERMASON, Predicted: DERMASON
# Actual: BOMBAY, Predicted: BOMBAY
# Actual: SIRA, Predicted: DERMASON
# Actual: HOROZ, Predicted: HOROZ
# Actual: SEKER, Predicted: SEKER
# Actual: CALI, Predicted: CALI
# Actual: SEKER, Predicted: SEKER
# Actual: SIRA, Predicted: DERMASON
# Actual: SIRA, Predicted: SIRA
# Actual: SEKER, Predicted: SEKER
# Actual: CALI, Predicted: CALI
# Actual: SEKER, Predicted: SIRA
# Actual: SEKER, Predicted: SEKER
# Actual: SEKER, Predicted: SEKER
# Actual: DERMASON, Predicted: DERMASON
# Actual: CALI, Predicted: CALI
# Actual: SEKER, Predicted: SEKER
# Actual: CALI, Predicted: CALI
# Actual: BARBUNYA, Predicted: CALI
# Actual: DERMASON, Predicted: DERMASON
# Actual: DERMASON, Predicted: DERMASON
# Actual: SIRA, Predicted: SIRA
# Actual: DERMASON, Predicted: SIRA
# Actual: SIRA, Predicted: SIRA
# Actual: SIRA, Predicted: SIRA
# Actual: SIRA, Predicted: SIRA
# Actual: DERMASON, Predicted: DERMASON
# Actual: DERMASON, Predicted: DERMASON
# Actual: SEKER, Predicted: SEKER
# Actual: CALI, Predicted: CALI
# Actual: HOROZ, Predicted: HOROZ
# Actual: DERMASON, Predicted: DERMASON
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: CALI, Predicted: CALI
# Actual: CALI, Predicted: CALI
# Actual: SIRA, Predicted: SIRA
# Actual: SEKER, Predicted: SEKER
# Actual: HOROZ, Predicted: HOROZ
# Actual: HOROZ, Predicted: HOROZ
# Actual: HOROZ, Predicted: HOROZ
# Actual: DERMASON, Predicted: DERMASON
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: SIRA, Predicted: SIRA
# Actual: DERMASON, Predicted: DERMASON
# Actual: CALI, Predicted: CALI
# Actual: DERMASON, Predicted: DERMASON
# Actual: SIRA, Predicted: SIRA
# Actual: SIRA, Predicted: SIRA
# Actual: SIRA, Predicted: SIRA
# Actual: DERMASON, Predicted: DERMASON
# Actual: SIRA, Predicted: SIRA
# Actual: HOROZ, Predicted: HOROZ
# Actual: HOROZ, Predicted: HOROZ
# Actual: HOROZ, Predicted: HOROZ
# Actual: BOMBAY, Predicted: BOMBAY
# Actual: SEKER, Predicted: SEKER
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: SIRA, Predicted: SIRA
# Actual: CALI, Predicted: CALI
# Actual: HOROZ, Predicted: SIRA
# Actual: HOROZ, Predicted: CALI
# Actual: SIRA, Predicted: SIRA
# Actual: HOROZ, Predicted: DERMASON
# Actual: CALI, Predicted: CALI
# Actual: DERMASON, Predicted: HOROZ
# Actual: HOROZ, Predicted: HOROZ
# Actual: SEKER, Predicted: SEKER
# Actual: SIRA, Predicted: SEKER
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: CALI, Predicted: CALI
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: SEKER, Predicted: SEKER
# Actual: HOROZ, Predicted: SIRA
# Actual: SEKER, Predicted: SEKER
# Actual: CALI, Predicted: CALI
# Actual: DERMASON, Predicted: DERMASON
# Actual: BOMBAY, Predicted: BOMBAY
# Actual: SEKER, Predicted: DERMASON
# Actual: DERMASON, Predicted: DERMASON
# Actual: DERMASON, Predicted: DERMASON
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: CALI, Predicted: CALI
# Actual: SIRA, Predicted: DERMASON
# Actual: DERMASON, Predicted: DERMASON
# Actual: DERMASON, Predicted: DERMASON
# Actual: SIRA, Predicted: SEKER
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: DERMASON, Predicted: SEKER
# Actual: CALI, Predicted: CALI
# Actual: DERMASON, Predicted: DERMASON
# Actual: HOROZ, Predicted: HOROZ
# Actual: HOROZ, Predicted: HOROZ
# Actual: DERMASON, Predicted: DERMASON
# Actual: DERMASON, Predicted: DERMASON
# Actual: DERMASON, Predicted: DERMASON
# Actual: SIRA, Predicted: SIRA
# Actual: SEKER, Predicted: SEKER
# Actual: HOROZ, Predicted: HOROZ
# Actual: SEKER, Predicted: SEKER
# Actual: CALI, Predicted: CALI
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: SIRA, Predicted: SIRA
# Actual: DERMASON, Predicted: SEKER
# Actual: DERMASON, Predicted: DERMASON
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: DERMASON, Predicted: SIRA
# Actual: DERMASON, Predicted: SIRA
# Actual: HOROZ, Predicted: HOROZ
# Actual: HOROZ, Predicted: HOROZ
# Actual: SIRA, Predicted: DERMASON
# Actual: DERMASON, Predicted: DERMASON
# Actual: HOROZ, Predicted: HOROZ
# Actual: CALI, Predicted: CALI
# Actual: BARBUNYA, Predicted: BARBUNYA
# Actual: SEKER, Predicted: DERMASON
# Actual: HOROZ, Predicted: HOROZ
# Actual: SEKER, Predicted: SEKER
# Actual: CALI, Predicted: CALI
# Actual: DERMASON, Predicted: DERMASON
#
# Model Accuracy: 89.50%
